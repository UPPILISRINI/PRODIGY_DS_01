# %%
import pandas as pd

# %%
df=pd.read_csv("/content/API_SP.POP.TOTL_DS2_en_csv_v2_85.csv")

# %%
df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'],
#       dtype='object')

# %%
# prompt: drop columns =['indicator Name','Indicatorcode',"country name']

df.drop(columns=['Indicator Name','Indicator Code','Country Name'],inplace=True)

# %%
df.head()
# Out:
#   Country Code         1960         1961         1962         1963  \
# 0          ABW      54608.0      55811.0      56682.0      57475.0
# 1          AFE  130692579.0  134169237.0  137835590.0  141630546.0
# 2          AFG    8622466.0    8790140.0    8969047.0    9157465.0
# 3          AFW   97256290.0   99314028.0  101445032.0  103667517.0
# 4          AGO    5357195.0    5441333.0    5521400.0    5599827.0
#
#           1964         1965         1966         1967         1968  ...  \
# 0      58178.0      58782.0      59291.0      59522.0      59471.0  ...
# 1  145605995.0  149742351.0  153955516.0  158313235.0  162875171.0  ...
# 2    9355514.0    9565147.0    9783147.0   10010030.0   10247780.0  ...
# 3  105959979.0  108336203.0  110798486.0  113319950.0  115921723.0  ...
# 4    5673199.0    5736582.0    5787044.0    5827503.0    5868203.0  ...
#
#           2013         2014         2015         2016         2017  \
# ...

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
df.isnull().sum()
# Out:
# Country Code    0
# 1960            2
# 1961            2
# 1962            2
# 1963            2
#                ..
# 2018            1
# 2019            1
# 2020            1
# 2021            1
# 2022            1
# Length: 64, dtype: int64

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# Country Code    0
# 1960            0
# 1961            0
# 1962            0
# 1963            0
#                ..
# 2018            0
# 2019            0
# 2020            0
# 2021            0
# 2022            0
# Length: 64, dtype: int64

# %%
# prompt: visualize the data frame

df.plot(figsize=(10,6))
plt.xlabel("Year")
plt.ylabel("Total Population")
plt.title("Total Population by Year")
plt.show()
